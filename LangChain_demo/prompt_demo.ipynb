# %% [markdown]
# # 大模型prompt

# %% [markdown]
# # 1. 构造input-输入数据（劣质报告）
# ## 1.1 构造动态提示词

# %%
import random

def generate_input_prompt():
    roles = ['初级产品经理', '高级项目经理', '技术负责人', '数据产品经理']
    tasks = ['工单流程开发', 'BI看板开发', '文本分类模型建设', '知识库建设', '对话智能体建设', '接口开发与联调', '数据中台建设', '用户画像标签体系建设', 
             '数据治理与质量监控','用户需求调研与分析', '跨部门沟通协调', '技术方案选型与评审', '数据备份与灾难恢复演练', '指标口径统一化建设']
    report_types = ['周报', '月报', '建设进展', '工作总结']
    word_counts = [80, 120, 150, 200]
    problem_categories = ['逻辑混乱', '口语化严重', '流水账', '缺乏数据支撑', '价值点缺失']
    
    role = random.choice(roles) # 4种组合
    task = random.choice(tasks) # 14种组合
    report_type = random.choice(report_types) # 4种组合
    word_count = random.choice(word_counts) # 4种组合
    selected_problems = random.sample(problem_categories, 3) # 5种组合
    
    prompt = f"""
                # 角色和要求
                作为{role}，请撰写一份关于{task}的{report_type}。这份报告应该是一个典型的"反面教材"。
                
                ## 需要突出的问题特征（重点体现：{', '.join(selected_problems)}）：
                - 逻辑不连贯，想到哪写到哪
                - 大量使用口语化、不专业的表达
                - 像记流水账一样罗列工作
                - 避免使用具体数据和量化结果
                - 只描述过程，不提炼价值和成果
                
                ## 写作要求：
                - 字数：{word_count}字左右
                - 内容要基于真实工作场景，但表达要糟糕
                - 避免刻意搞笑或夸张，要像真实工作中会出现的低质量报告
            """
    
    return prompt, {
        "role": role,
        "task": task,
        "report_type": report_type,
        "word_count": word_count,
        "problem_types": selected_problems
    }

# 使用示例
prompt, metadata = generate_input_prompt()
print("生成的提示词：")
print(prompt)
print("\n样本元数据：", metadata)
# Out:
# 生成的提示词：
#
#                 # 角色和要求
#                 作为高级项目经理，请撰写一份关于指标口径统一化建设的月报。这份报告应该是一个典型的"反面教材"。
#
#                 ## 需要突出的问题特征（重点体现：价值点缺失, 缺乏数据支撑, 流水账）：
#                 - 逻辑不连贯，想到哪写到哪
#                 - 大量使用口语化、不专业的表达
#                 - 像记流水账一样罗列工作
#                 - 避免使用具体数据和量化结果
#                 - 只描述过程，不提炼价值和成果
#
#                 ## 写作要求：
#                 - 字数：80字左右
#                 - 内容要基于真实工作场景，但表达要糟糕
#                 - 避免刻意搞笑或夸张，要像真实工作中会出现的低质量报告
#
#
# 样本元数据： {'role': '高级项目经理', 'task': '指标口径统一化建设', 'report_type': '月报', 'word_count': 80, 'problem_types': ['价值点缺失', '缺乏数据支撑', '流水账']}

# %% [markdown]
# ## 1.2 调用大模型，生成“劣质报告”

# %%
from openai import OpenAI

client = OpenAI(
    api_key="sk-cp-cCklcsA3A7xhoFLbQvAKlZCQ3t19DKYO__BJ-QXrs3PH4ED3VELD37UG4Gl2TYShKMUVl9G5mLWb6mgKXz4Ju6ceP-6mzLP10rRCYAp7YHTUFQCqUQuELDc",
    base_url="https://api.minimaxi.com/v1"
)

def generate_input_sample():
    """生成单个样本的辅助函数"""
    prompt, _ = generate_input_prompt()
    
    response = client.chat.completions.create(
        model="MiniMax-M2.7",
        messages=[{"role": "user", "content": prompt}]
    )
    
    return response.choices[0].message.content

reulst = generate_input_sample()
print(reulst)
# Out:
# <think>
# 好的，我需要作为数据产品经理撰写一份关于用户需求调研与分析的月报，这份报告需要是一个典型的“反面教材”。关键要求是：
#
# 1. **问题特征**：
#    - 逻辑不连贯，想到哪写到哪
#    - 大量使用口语化、不专业的表达
#    - 像记流水账一样罗列工作
#    - 避免使用具体数据和量化结果
#    - 只描述过程，不提炼价值和成果
#
# 2. **写作要求**：
#    - 字数：200字左右
#    - 内容要基于真实工作场景，但表达要糟糕
#    - 避免刻意搞笑或夸张，要像真实工作中会出现的低质量报告
#
# 让我开始撰写这份月报，确保符合所有要求。
#
# ---
#
# **用户需求调研与分析月报**
#
# **本月工作概述**
#
# 这个月我们做了不少调研的事情吧应该。有去拜访一些客户聊了聊，反正就是问问他们想要什么功能，感觉有些人说的挺好的，有些人说的也不太靠谱。我们还做了几个问卷，发给了一些用户，收回来一些吧，数量我记不太清了，大概几十份？问卷设计的时候改了几次，因为总觉得不太对。
#
# 然后还组织了几次内部讨论，大家坐在一起头脑风暴了一下，提了很多点子，有些想法确实挺有意思的，但后来也没整理出个所以然。
#
# **存在的问题**
#
#
# 调研方法显得随意且缺乏系统性。我对收集到的信息没有进行深入分析，只是简单记录，没有形成清晰的需求优先级排序。沟通中存在明显的逻辑漏洞，表达方式过于口语化。
#
# 我发现自己只是机械地完成工作流程，没有真正理解用户需求的核心价值。报告更像是一个简单的工作清单，而不是有深度的分析文档。
# </think>
#
# **用户需求调研与分析月报**
#
# **本月工作概述**
#
# 这个月我们做了不少调研的事情吧应该。有去拜访一些客户聊了聊，反正就是问问他们想要什么功能，感觉有些人说的挺好的，有些人说的也不太靠谱。我们还做了几个问卷，发给了一些用户，收回来一些吧，数量我记不太清了，大概几十份？问卷设计的时候改了几次，因为总觉得不太对。
#
# 然后还组织了几次内部讨论，大家坐在一起头脑风暴了一下，提了很多点子，有些想法确实挺有意思的，但后来也没整理出个所以然。
#
# **下一步计划**
#
# 接下来可能还会继续做调研吧，或者先把之前的东西理一理，不过也不着急，看情况再说。

# %%
num_samples = 2
results=[]
for i in range(num_samples):
    
    # 获取结果
    result = generate_input_sample()
    
    # 添加到结果列表
    results.append(result)

print("数据生成完成!")
results
# Out:
# 数据生成完成!
# ['<think>\n用户需要我扮演技术负责人角色，撰写一份关于"数据治理与质量监控"的月报，要求是写成一个"反面教材"。\n\n关键要求：\n1. 逻辑不连贯，想到哪写到哪\n2. 大量口语化、不专业表达\n3. 像记流水账\n4. 避免具体数据和量化结果\n5. 只描述过程，不提炼价值\n6. 120字左右\n7. 要像真实工作中的低质量报告，但不要刻意搞笑\n\n让我来写一份这样的反面教材报告：\n</think>\n\n# 数据治理与质量监控月报\n\n本月主要做了些数据方面的工作。数据质量这块，我们对一些数据进行了清洗，修正了一些问题字段。治理方面开了几次会，讨论了相关方案。技术上做了几个脚本用来跑数据，还改进了数据库的某些配置。团队这边也有人员参与配合。不过具体效果还得再看看，后续可能还会继续优化。有问题再同步。',
#  '<think>\n用户要求我作为初级产品经理撰写一份关于"指标口径统一化建设"的工作总结，但要求写成"反面教材"——即要体现出流水账、缺乏数据支撑、价值点缺失等问题。\n\n关键要求：\n1. 150字左右\n2. 体现逻辑不连贯、口语化、流水账罗列\n3. 避免数据和量化结果\n4. 只描述过程，不提炼价值\n5. 要像真实工作中的低质量报告\n\n我需要写一个看起来像是初级PM会写的糟糕的工作总结，但实际上要通过这种糟糕的写法来示范什么是"反面教材"。\n\n让我写一个符合这些要求的报告：\n</think>\n\n# 指标口径统一化建设工作总结\n\n这季度主要做了指标口径统一的工作。一开始跟数据那边开了几次会，后来又拉了业务部门一起讨论。中间改了好几版文档，有些指标定义什么的搞了很久。\n\n基本上就是把各个系统的指标梳理了一遍，有些口径对不上的就调整了一下。技术那边也配合改了改报表。感觉流程挺复杂的，大家沟通起来也挺费劲的。\n\n下一步可能还要继续优化吧，看领导怎么安排。']

# %% [markdown]
# ## 1.3 保存数据，并人工抽样检查，适时调整提示词

# %%
 # 保存到JSON文件
from datetime import datetime
import json

filename = f"distill_input.json"

with open(filename, 'w', encoding='utf-8') as f:
    json.dump(results, f, ensure_ascii=False, indent=2)

print(f"结果已保存到: {filename}")
# Out:
# 结果已保存到: distill_input.json

# %% [markdown]
# # 二、生成output-输出数据（优质报告）
# ## 2.1 构造提示词

# %%
    
def generate_output_prompt(original_text):
    return f"""
        你现在是一位经验丰富的办公室秘书，擅长将普通文本优化为专业、结构清晰、符合领导预期的优质报告。请根据提供的普通文本，进行以下优化：
        
        ## 核心要求
        请务必在报告中体现以下要素：
        1. 战略格局：将工作成果与公司“降本增效”/“技术驱动业务”等核心战略联系起来。
        2. 逻辑清晰：采用“总-分-总”结构，分点阐述，条理分明。
        3. 数据支撑：尽可能量化成果，使用具体数据（如效率提升百分比、节省工时、处理数据量等）来增强说服力。
        4. 语言专业：使用规范、专业的书面语和技术术语，避免口语化表达。
        5. 亮点突出：不仅要写“做了什么”，更要强调“取得了什么成果”和“带来了什么价值”。
        6. 计划明确：给出清晰、可量化的下一步行动计划。
        
        ## 参考案例
        【案例1】
        修改前：“这周就是搞那个新的数据看板，把几个图表弄上去了，反正数据都能显示了，具体啥意思让业务自己看吧，差不多了。”
        修改后：【BI看板开发】本周完成了销售业绩实时监控看板的开发与上线，整合了订单、用户、渠道等5个核心数据源，实现了关键指标T+1的自动更新。该看板已赋能销售部门自主进行日度业绩追踪，预计每周可节省数据提取和手工制表工时约15人时，为精细化运营决策提供了即时数据支撑。
        ## 待优化的文本
        {original_text}
    """

# %% [markdown]
# ## 2.2 载入“劣质报告”，生成“优质报告”

# %%
import json
import pprint
with open(f"distill_input.json", 'r', encoding='utf-8') as f:
    input_distill = json.load(f)
    
finetune_results = []
for i,original_text in enumerate(input_distill):
    prompt = generate_output_prompt(original_text)
    response = client.chat.completions.create(
        model="MiniMax-M2.7",
        messages=[{"role": "user", "content": prompt}]
    )
    
    # 按照alpaca格式存储
    finetune_results.append(
        {
            "instruction":"优化报告",
            "input":original_text,
            "output": response.choices[0].message.content
        }
    )
    
pprint.pprint(finetune_results)
#  print("message.__dict__:", response.__dict__)
# Out:
# [{'input': '<think>\n'
#            '用户需要我扮演技术负责人角色，撰写一份关于"数据治理与质量监控"的月报，要求是写成一个"反面教材"。\n'
#            '\n'
#            '关键要求：\n'
#            '1. 逻辑不连贯，想到哪写到哪\n'
#            '2. 大量口语化、不专业表达\n'
#            '3. 像记流水账\n'
#            '4. 避免具体数据和量化结果\n'
#            '5. 只描述过程，不提炼价值\n'
#            '6. 120字左右\n'
#            '7. 要像真实工作中的低质量报告，但不要刻意搞笑\n'
#            '\n'
#            '让我来写一份这样的反面教材报告：\n'
#            '</think>\n'
#            '\n'
#            '# 数据治理与质量监控月报\n'
#            '\n'
#            '本月主要做了些数据方面的工作。数据质量这块，我们对一些数据进行了清洗，修正了一些问题字段。治理方面开了几次会，讨论了相关方案。技术上做了几个脚本用来跑数据，还改进了数据库的某些配置。团队这边也有人员参与配合。不过具体效果还得再看看，后续可能还会继续优化。有问题再同步。',
#   'instruction': '优化报告',
#   'output': '<think>\n'
#             'The user is requesting a "counter-example" (反面教材) monthly report '
#             'about "Data Governance and Quality Monitoring". They want me to '
#             'write a poorly structured, unprofessional report that:\n'
#             '\n'
#             '1. Lacks logical coherence\n'
#             '2. Uses casual, unprofessional language\n'
#             '3. Reads like a stream of consciousness /流水账\n'
#             '4. Avoids specific data and quantified results\n'
#             "5. Only describes processes, doesn't extract value\n"
#             '6. Around 120 characters\n'
#             '7. Should look like a real low-quality work report but not '
#             'deliberately comedic\n'
#             '\n'
#             'Let me craft this:\n'
#             '\n'
#             '关键要素：\n'
#             '- 逻辑混乱：东一榔头西一棒槌，想到什么说什么\n'
#             '- 口语化："做了些"、"乱七八糟"、"好像"、"估计"\n'
#             '- 没有数据：全是模糊描述，没有指标\n'
#             '- 无价值提炼：只说做了什么，不说意义和成果\n'
#             '- 像流水账：工作罗列，没有重点\n'
#             '\n'
#             '我写的这份报告：\n'
#             '- 大约120字左右\n'
#             '- 结构混乱（从数据质量到开会到技术到人员）\n'
#             '- 口语化表达多\n'
#             '- 没有量化指标\n'
#             '- 缺乏逻辑衔接\n'
#             '</think>\n'
#             '\n'
#             '# 数据治理与质量监控月报\n'
#             '\n'
#             '本月主要做了些数据方面的工作。数据质量这块，我们对一些数据进行了清洗，修正了一些问题字段。治理方面开了几次会，讨论了相关方案。技术上做了几个脚本用来跑数据，还改进了数据库的某些配置。团队这边也有人员参与配合。不过具体效果还得再看看，后续可能还会继续优化。有问题再同步。'},
#  {'input': '<think>\n'
#            '用户要求我作为初级产品经理撰写一份关于"指标口径统一化建设"的工作总结，但要求写成"反面教材"——即要体现出流水账、缺乏数据支撑、价值点缺失等问题。\n'
#            '\n'
#            '关键要求：\n'
#            '1. 150字左右\n'
#            '2. 体现逻辑不连贯、口语化、流水账罗列\n'
#            '3. 避免数据和量化结果\n'
#            '4. 只描述过程，不提炼价值\n'
#            '5. 要像真实工作中的低质量报告\n'
#            '\n'
#            '我需要写一个看起来像是初级PM会写的糟糕的工作总结，但实际上要通过这种糟糕的写法来示范什么是"反面教材"。\n'
#            '\n'
#            '让我写一个符合这些要求的报告：\n'
#            '</think>\n'
#            '\n'
#            '# 指标口径统一化建设工作总结\n'
#            '\n'
#            '这季度主要做了指标口径统一的工作。一开始跟数据那边开了几次会，后来又拉了业务部门一起讨论。中间改了好几版文档，有些指标定义什么的搞了很久。\n'
#            '\n'
#            '基本上就是把各个系统的指标梳理了一遍，有些口径对不上的就调整了一下。技术那边也配合改了改报表。感觉流程挺复杂的，大家沟通起来也挺费劲的。\n'
#            '\n'
#            '下一步可能还要继续优化吧，看领导怎么安排。',
#   'instruction': '优化报告',
#   'output': '<think>\n'
#             '这个"反面教材"工作总结确实体现了几个明显的问题：\n'
#             '\n'
#             '1. **流水账式表述**：用了"主要做了"、"后来又"、"中间改了"等词汇，描述非常散乱\n'
#             '2. **缺乏逻辑连贯性**：没有清晰的工作框架，想到什么说什么\n'
#             '3. **没有数据支撑**：完全没有提及覆盖了多少指标、统一了多少口径、提升了多少效率\n'
#             '4. **口语化严重**："感觉"、"挺复杂的"、"也挺费劲的"\n'
#             '5. **没有价值提炼**：只说"做了"，不说"做到了什么"\n'
#             '6. **缺乏成果描述**：下一步计划模糊，"看领导怎么安排"显得被动\n'
#             '\n'
#             '这是一个真实的、符合要求的"反面教材"示范。\n'
#             '</think>\n'
#             '\n'
#             '# 指标口径统一化建设工作总结\n'
#             '\n'
#             '这季度主要做了指标口径统一的工作。一开始跟数据那边开了几次会，后来又拉了业务部门一起讨论。中间改了好几版文档，有些指标定义什么的搞了很久。\n'
#             '\n'
#             '基本上就是把各个系统的指标梳理了一遍，有些口径对不上的就调整了一下。技术那边也配合改了改报表。感觉流程挺复杂的，大家沟通起来也挺费劲的。\n'
#             '\n'
#             '下一步可能还要继续优化吧，看领导怎么安排。\n'
#             '\n'
#             '---\n'
#             '\n'
#             '**问题分析**：\n'
#             '\n'
#             '| 问题类型 | 具体表现 |\n'
#             '|---------|---------|\n'
#             '| 流水账式写法 | "主要做了"、"后来又"、"中间改了"等词汇堆砌 |\n'
#             '| 逻辑不连贯 | 没有工作框架，想到什么说什么 |\n'
#             '| 无数据支撑 | 未提及覆盖指标数、统一口径数、效率提升等 |\n'
#             '| 口语化严重 | "感觉"、"挺复杂的"、"也挺费劲的" |\n'
#             '| 缺乏价值点 | 只说"做了"，不说"做到了什么" |\n'
#             '| 成果模糊 | 调整了什么？没有量化结果 |\n'
#             '\n'
#             '如需改造成正面版本，我可提供优化示例。'}]
# message.__dict__: {'id': '063b583e3e2f80dfc6f4d11331644d58', 'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='<think>\n这个"反面教材"工作总结确实体现了几个明显的问题：\n\n1. **流水账式表述**：用了"主要做了"、"后来又"、"中间改了"等词汇，描述非常散乱\n2. **缺乏逻辑连贯性**：没有清晰的工作框架，想到什么说什么\n3. **没有数据支撑**：完全没有提及覆盖了多少指标、统一了多少口径、提升了多少效率\n4. **口语化严重**："感觉"、"挺复杂的"、"也挺费劲的"\n5. **没有价值提炼**：只说"做了"，不说"做到了什么"\n6. **缺乏成果描述**：下一步计划模糊，"看领导怎么安排"显得被动\n\n这是一个真实的、符合要求的"反面教材"示范。\n</think>\n\n# 指标口径统一化建设工作总结\n\n这季度主要做了指标口径统一的工作。一开始跟数据那边开了几次会，后来又拉了业务部门一起讨论。中间改了好几版文档，有些指标定义什么的搞了很久。\n\n基本上就是把各个系统的指标梳理了一遍，有些口径对不上的就调整了一下。技术那边也配合改了改报表。感觉流程挺复杂的，大家沟通起来也挺费劲的。\n\n下一步可能还要继续优化吧，看领导怎么安排。\n\n---\n\n**问题分析**：\n\n| 问题类型 | 具体表现 |\n|---------|---------|\n| 流水账式写法 | "主要做了"、"后来又"、"中间改了"等词汇堆砌 |\n| 逻辑不连贯 | 没有工作框架，想到什么说什么 |\n| 无数据支撑 | 未提及覆盖指标数、统一口径数、效率提升等 |\n| 口语化严重 | "感觉"、"挺复杂的"、"也挺费劲的" |\n| 缺乏价值点 | 只说"做了"，不说"做到了什么" |\n| 成果模糊 | 调整了什么？没有量化结果 |\n\n如需改造成正面版本，我可提供优化示例。', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, name='MiniMax AI', audio_content=''))], 'created': 1777083710, 'model': 'MiniMax-M2.7', 'object': 'chat.completion', 'service_tier': None, 'system_fingerprint': None, 'usage': CompletionUsage(completion_tokens=364, prompt_tokens=270, total_tokens=634, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=143, rejected_prediction_tokens=None), prompt_tokens_details=None, total_characters=0), '_request_id': None}

# %% [markdown]
# ## 2.3 载入“劣质报告”，生成“优质报告”（有思考模式）

# %%
import json
import pprint
with open(f"distill_input.json", 'r', encoding='utf-8') as f:
    input_distill = json.load(f)
    
finetune_results = []
for i,original_text in enumerate(input_distill):
    prompt = generate_output_prompt(original_text)
    response = client.chat.completions.create(
        model="glm-4.5-x", # 1.模型得具备输出思维链的能力
        messages=[{"role": "user", "content": prompt}],
        top_p=0.8,
        temperature=0.9,
        extra_body={"thinking": {"type": "enabled",}} # 2.要在参数中启用思考模式
    )
    message= response.choices[0].message 
    finetune_results.append(
        {
            "instruction":"优化报告",
            "input":original_text,
            "output":"<think>"+ message.reasoning_content +"</think>\n"+  message.content      # 3.将整出输出和思维链数据拼接起来
        }
    )
    
pprint.pprint(finetune_results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 21
#       9     response = client.chat.completions.create(
#      10         model="MiniMax-M2.5", # 1.模型得具备输出思维链的能力
#      11         messages=[{"role": "user", "content": prompt}],
#    (...)
#      14         extra_body={"thinking": {"type": "enabled",}} # 2.要在参数中启用思考模式
#      15     )
#      16     message= response.choices[0].message
#      17     finetune_results.append(
#      18         {
#      19             "instruction":"优化报告",
#      20             "input":original_text,
# ---> 21             "output":"<think>"+ message.reasoning_content +"</think>\n"+  message.content      # 3.将整出输出和思维链数据拼接起来
#      22         }
#      23     )
#      25 pprint.pprint(finetune_results)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pydantic\main.py:1042, in BaseModel.__getattr__(self, item)
#    1039     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#    1040 else:
#    1041     # this is the current error
# -> 1042     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'ChatCompletionMessage' object has no attribute 'reasoning_content'
